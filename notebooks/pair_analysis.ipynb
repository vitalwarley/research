# %%
import math
import random
from itertools import combinations

import numpy as np

# %%
import pandas as pd

# %%
# Initialize variables
n_rows = 33
letters = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
age_diff_distributions = {
    "fs": ("gaussian", 26.11, 11.24),
    "fd": ("gaussian", 27.88, 11.48),
    "ms": ("gaussian", 22.52, 9.88),
    "md": ("gaussian", 22.53, 10.02),
    "gfgs": ("gaussian", 38.24, 18.47),
    "gfgd": ("gaussian", 37.90, 18.31),
    "gmgs": ("gaussian", 32.78, 17.04),
    "gmgd": ("gaussian", 35.53, 17.63),
    "bb": ("power-law", 1, 1),
    "ss": ("power-law", 1, 1),
    "sibs": ("power-law", 1, 1),
}
gender_constraints = {
    "fs": ("male", "male"),
    "fd": ("male", "female"),
    "ms": ("female", "male"),
    "md": ("female", "female"),
    "gfgs": ("male", "male"),
    "gfgd": ("male", "female"),
    "gmgs": ("female", "male"),
    "gmgd": ("female", "female"),
    "bb": ("male", "male"),
    "ss": ("female", "female"),
    "sibs": ("either", "either"),
}

# %%
# Function to generate age difference
def generate_age_diff(distribution, *params):
    if distribution == "gaussian":
        mean, std_dev = params
        return max(0, np.random.normal(mean, std_dev))
    else:
        constant, exponent = params
        return max(0, np.random.pareto(exponent) + constant)

# %%
# Create df_final
df_final = pd.DataFrame(columns=["x1", "x2", "age_x1", "age_x2", "gender_x1", "gender_x2", "kinship_type", "age_diff"])

for i in range(n_rows):
    letter = random.choice(letters)
    x1 = f"{letter}{random.randint(1, 100)}"
    x2 = f"{letter}{random.randint(1, 100)}"
    kinship_type = random.choice(list(age_diff_distributions.keys()))
    gender_x1, gender_x2 = gender_constraints[kinship_type]
    if gender_x1 == "either":
        gender_x1 = random.choice(["male", "female"])
    if gender_x2 == "either":
        gender_x2 = random.choice(["male", "female"])
    distribution, *params = age_diff_distributions[kinship_type]
    age_diff = generate_age_diff(distribution, *params)
    age_x1 = random.randint(1, 100)
    age_x2 = max(0, int(age_x1 - age_diff)) if age_x1 >= age_diff else int(age_x1 + age_diff)
    if random.choice([True, False]):
        x1, x2 = x2, x1
        age_x1, age_x2 = age_x2, age_x1
        gender_x1, gender_x2 = gender_x2, gender_x1
    df_final.loc[i] = [x1, x2, age_x1, age_x2, gender_x1, gender_x2, kinship_type, math.ceil(age_diff)]

df_final
# Out:
#      x1    x2  age_x1  age_x2 gender_x1 gender_x2 kinship_type  age_diff
# 0   Y40   Y40      46      68    female    female           md        22
# 1   T75   T40      18      37    female    female           md        20
# 2   K59   K59      42      40      male      male         sibs         2
# 3    Y2   Y70      31       1      male    female         gmgs        31
# 4   K29   K49      35      48    female    female           md        13
# 5   D47   D62      80      15    female      male         gfgd        66
# 6   T61   T40      53      14      male      male         gfgs        39
# 7   L25   L20      39       6      male      male           fs        34
# 8   N48   N56      62      60      male      male           bb         2
# 9   C77   C76      53      23    female    female           md        31
# 10  N76   N97      46      48      male      male         sibs         2
# 11  D63   D56      15      59    female    female         gmgd        45
# 12  H43   H77      14      36      male    female           fd        23
# 13  X14   X49      48      29    female      male           ms        19
# 14  G94    G1      85      67      male    female           fd        18
# 15  X86   X37      70      50    female      male         gmgs        20
# 16   U5   U82      16      18    female    female         sibs         2
# 17  N90   N38      28       3    female      male           ms        25
# 18  T51   T95      43      25      male    female         gfgd        18
# 19  Z40   Z27      46      23    female    female           md        24
# 20  F77  F100      87      28      male      male         gfgs        59
# 21  T34    T2      61      80      male    female           ms        19
# 22  F11   F85      47       3      male      male         gfgs        45
# 23  O28   O38      47       2      male    female         gfgd        45
# 24  B75   B16       8      32    female      male           fd        24
# 25  V59   V96      89      75      male      male           fs        14
# 26   F1   F19      13       1    female    female         gmgd        13
# 27  R70   R47      28      66      male      male           fs        38
# 28  K55   K25      35      37      male      male         sibs         2
# 29  X85   X92      10      14    female    female           ss         4
# 30  A65   A79      31      38    female      male           fd         7
# 31  X53   X11      74      71    female    female         sibs         3
# 32  N83   N73      14      13      male    female         gfgd         1

# %%
# Create df_pairwise
kinship_mapping = {
    "fs": "father-son",
    "fd": "father-daughter",
    "ms": "mother-son",
    "md": "mother-daughter",
    "bb": "brother-brother",
    "ss": "sister-sister",
    "sibs": "siblings",
    "gfgs": "grandfather-grandson",
    "gfgd": "grandfather-granddaughter",
    "gmgs": "grandmother-grandson",
    "gmgd": "grandmother-granddaughter",
}
rows = []
for (idx1, row1), (idx2, row2) in combinations(df_final.iterrows(), 2):
    age_diff = abs(row1["age_x1"] - row2["age_x1"])
    if row1["kinship_type"] == "sibs":
        first_term = "siblings"
    else:
        first_term = kinship_mapping[row1["kinship_type"]].split("-")[0]
    if row2["kinship_type"] == "sibs":
        second_term = "siblings"
    else:
        second_term = kinship_mapping[row2["kinship_type"]].split("-")[-1]
    new_kinship_type = first_term + "-" + second_term
    rows.append(
        {
            "x1": row1["x1"],
            "x2": row2["x1"],
            "age_x1": row1["age_x1"],
            "age_x2": row2["age_x1"],
            "gender_x1": row1["gender_x1"],
            "gender_x2": row2["gender_x1"],
            "age_diff": age_diff,
            "kinship_type": new_kinship_type,
        }
    )
df_pairwise = pd.DataFrame(rows)

# %%
# Add is_kin and age_diff columns
df_final["is_kin"] = 1
df_pairwise["is_kin"] = 0
df_pairwise.rename(columns={"new_kinship_type": "kinship_type"}, inplace=True)

# %%
# Merge to create df_merged
df_merged = pd.concat([df_final, df_pairwise], ignore_index=True)

# %%
df_merged
# Out:
#       x1   x2  age_x1  age_x2 gender_x1 gender_x2            kinship_type  \
# 0    Y40  Y40      46      68    female    female                      md
# 1    T75  T40      18      37    female    female                      md
# 2    K59  K59      42      40      male      male                    sibs
# 3     Y2  Y70      31       1      male    female                    gmgs
# 4    K29  K49      35      48    female    female                      md
# ..   ...  ...     ...     ...       ...       ...                     ...
# 556  X85  X53      10      74    female    female         sister-siblings
# 557  X85  N83      10      14    female      male    sister-granddaughter
# 558  A65  X53      31      74    female    female         father-siblings
# 559  A65  N83      31      14    female      male    father-granddaughter
# 560  X53  N83      74      14    female      male  siblings-granddaughter
#
#      age_diff  is_kin
# 0          22       1
# 1          20       1
# 2           2       1
# 3          31       1
# 4          13       1
# ..        ...     ...
# 556        64       0
# 557         4       0
# 558        43       0
# 559        17       0
# 560        60       0
#
# [561 rows x 9 columns]

# %%
df_merged.sample(n=10)
# Out:
#       x1   x2  age_x1  age_x2 gender_x1 gender_x2               kinship_type  \
# 540   F1  R70      13      28    female      male            grandmother-son
# 477  Z40  R70      46      28    female      male                 mother-son
# 555  X85  A65      10      31    female    female            sister-daughter
# 327  N76  A65      46      31      male    female          siblings-daughter
# 38   Y40  T61      46      53    female      male            mother-grandson
# 127   Y2  D47      31      80      male    female  grandmother-granddaughter
# 167  K29  N90      35      28    female    female                 mother-son
# 280  N48  K55      62      35      male      male           brother-siblings
# 332  D63  G94      15      85    female      male       grandmother-daughter
# 97   K59  K29      42      35      male    female          siblings-daughter
#
#      age_diff  is_kin
# 540        15       0
# 477        18       0
# 555        21       0
# 327        15       0
# 38          7       0
# 127        49       0
# 167         7       0
# 280        27       0
# 332        70       0
# 97          7       0

# %%
df_merged[df_merged.x1 == "F1"]
# Out:
#      x1   x2  age_x1  age_x2 gender_x1 gender_x2               kinship_type  \
# 26   F1  F19      13       1    female    female                       gmgd
# 540  F1  R70      13      28    female      male            grandmother-son
# 541  F1  K55      13      35    female      male       grandmother-siblings
# 542  F1  X85      13      10    female    female         grandmother-sister
# 543  F1  A65      13      31    female    female       grandmother-daughter
# 544  F1  X53      13      74    female    female       grandmother-siblings
# 545  F1  N83      13      14    female      male  grandmother-granddaughter
#
#      age_diff  is_kin
# 26         13       1
# 540        15       0
# 541        22       0
# 542         3       0
# 543        18       0
# 544        61       0
# 545         1       0
